# %%
6/2
# Out:
# 3.0

# %%
type(6/2)
# Out:
# float

# %%
6//2
# Out:
# 3

# %%
type(6//2)
# Out:
# int

# %%
"hello"=="world"
# Out:
# False

# %%
type("hello"=="world")
# Out:
# bool

# %%
str(1234567890)
# Out:
# '1234567890'

# %%
financial_value_str = "1234.56"
financial_value_float = float(financial_value_str)
print(financial_value_float)
print(type(financial_value_float))
# Out:
# 1234.56
# <class 'float'>

# %%
emp_id = "1001"
emp_id_int = int(emp_id)
print(emp_id_int)
print(type(emp_id_int))
# Out:
# 1001
# <class 'int'>

# %%
int(3.99)
# Out:
# 3
